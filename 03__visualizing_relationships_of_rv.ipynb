# %% [markdown]
# # Visualizing Relationships of random variables

# %%
import io
import matplotlib
import matplotlib.pyplot as plt
import numpy
import pandas as pd
import seaborn as sns

sns.set_context('talk')

# %%
url = 'https://www.famaf.unc.edu.ar/~nocampo043/sysarmy_survey_2020_processed.csv'
df = pd.read_csv(url)

# %%
df.head(3)
# Out:
#   profile_gender  profile_age work_country                    work_province  \
# 0         Female           26    Argentina  Ciudad Autónoma de Buenos Aires
# 1           Male           29    Argentina                       Corrientes
# 2         Female           22    Argentina  Ciudad Autónoma de Buenos Aires
#
#    profile_years_experience  work_years_in_company  \
# 0                       3.0                    3.0
# 1                       5.0                    2.0
# 2                       2.0                    0.0
#
#    work_years_in_current_position  work_people_in_charge_of  \
# 0                             3.0                         0
# 1                             2.0                         4
# 2                             0.0                         0
#
#   profile_studies_level profile_studies_level_state  ...    salary_has_bonus  \
# 0            University                     Ongoing  ...                  No
# 1            University                     Ongoing  ...  Less than a salary
# 2             Secondary                    Complete  ...          One salary
#
#   salary_inflation_adjustment_2020  \
# 0                               No
# 1                              One
# 2                               No
#
#   salary_percentage_inflation_adjustment_2020  \
# 0                                         0.0
# 1                                        10.0
# 2                                         0.0
#
#   salary_month_last_inflation_adjustment work_has_violence_situations  \
# 0                                      0            In my current job
# 1                                      1                        Never
# 2                                      0            In a previous job
#
#   profile_has_disabilities_hiring_difficulties company_employee_number  \
# 0                                          NaN                501-1000
# 1                                           No                 201-500
# 2                                           No               2001-5000
#
#                       company_main_activity company_recommended  \
# 0  Services / Software Consulting / Digital                   7
# 1                          Other industries                   8
# 2                          Other industries                   6
#
#   company_diversity_policies
# 0                          2
# 1                          9
# 2                          9
#
# [3 rows x 43 columns]

# %% [markdown]
# ## Numerical random variables

# %% [markdown]
# Machine learning algorithms strongly depend on providing correlated information of your input with the output, and removing duplicated information, that is, data that is correlated. For example:
#
# - If you have annotated values of house prices in Melbourne, that is, we want to predict the prices of houses in Melbourne according to other sales in the zone. The objective is to find a random variable (column) that is correlated to the

# %%
max_age = 99
sns.pairplot(data=df[df.profile_age < max_age],
             y_vars=['profile_age', 'salary_monthly_GROSS'],
             x_vars=['salary_monthly_NET', 'salary_monthly_GROSS'],
             aspect=2, height=5)

# %%
df[["salary_monthly_NET", "salary_monthly_GROSS"]].corr()
# Out:
#                       salary_monthly_NET  salary_monthly_GROSS
# salary_monthly_NET              1.000000              0.833335
# salary_monthly_GROSS            0.833335              1.000000

# %%
df[["profile_age", "salary_monthly_GROSS"]].corr()
# Out:
#                       profile_age  salary_monthly_GROSS
# profile_age              1.000000             -0.006752
# salary_monthly_GROSS    -0.006752              1.000000

# %% [markdown]
# ## Categorical Random Variables

# %%
sorted_studies_levels = ["Primary", "Secondary", "Terciary", "University", "Postgraduate", "Doctorate", "Postdoc"]
pd.crosstab(df.profile_gender, df.profile_studies_level, margins=True)[sorted_studies_levels + ["All"]]
# Out:
# profile_studies_level  Primary  Secondary  Terciary  University  Postgraduate  \
# profile_gender
# Female                       0         24       158         667            85
# Male                         2        424       970        3447           256
# Other                        0          1         7          19             1
# All                          2        449      1135        4133           342
#
# profile_studies_level  Doctorate  Postdoc   All
# profile_gender
# Female                         8        0   942
# Male                          19        4  5122
# Other                          3        0    31
# All                           30        4  6095

# %%
fig = plt.figure(figsize=(16, 8))
exp = pd.crosstab(df.profile_gender,
                  df.profile_studies_level)[sorted_studies_levels]
sns.heatmap(exp, annot=True, fmt='g')
# Out:
# <AxesSubplot:xlabel='profile_studies_level', ylabel='profile_gender'>

# %%
pd.crosstab(df.profile_gender, df.profile_studies_level, normalize=True, margins=True)[sorted_studies_levels + ["All"]]
# Out:
# profile_studies_level   Primary  Secondary  Terciary  University  \
# profile_gender
# Female                 0.000000   0.003938  0.025923    0.109434
# Male                   0.000328   0.069565  0.159147    0.565546
# Other                  0.000000   0.000164  0.001148    0.003117
# All                    0.000328   0.073667  0.186218    0.678097
#
# profile_studies_level  Postgraduate  Doctorate   Postdoc       All
# profile_gender
# Female                     0.013946   0.001313  0.000000  0.154553
# Male                       0.042002   0.003117  0.000656  0.840361
# Other                      0.000164   0.000492  0.000000  0.005086
# All                        0.056112   0.004922  0.000656  1.000000

# %%
fig = plt.figure(figsize=(10,8))
sns.countplot(data=df, x="profile_studies_level", hue=df.profile_gender, order=sorted_studies_levels)
plt.xticks(rotation=45)
plt.legend(loc='upper right')

# %% [markdown]
# ## Mixing categorical and numerical variables

# %%
df_lt_200k_salary = df[df["salary_monthly_NET"] < 200000]

sns.displot(data=df_lt_200k_salary, x="salary_monthly_NET", hue="profile_gender")

# %%
fig = plt.figure(figsize=(10,8))
sns.scatterplot(data=df[df.profile_age < max_age],
                y='salary_monthly_NET',
                x='salary_satisfaction')
# Out:
# <AxesSubplot:xlabel='salary_satisfaction', ylabel='salary_monthly_NET'>

# %%
sns.catplot(data=df[df.profile_age < max_age],
            y='salary_monthly_NET',
            x='salary_satisfaction',
            height=4,
            aspect=2)
